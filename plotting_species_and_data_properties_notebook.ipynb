# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
plt.rcParams['font.family'] = 'Arial'

# %%
df_lb_all_taxa_trees = pd.read_csv("lb_all_species_both_models_species_values.txt", sep="\t",header=None)
df_lb_all_taxa_trees.columns=["Species","LB score","Model"]

# %%
df_lb_all_taxa_trees
# Out:
#                      Species  LB score               Model
# 0            Adineta_ricciae  -32.8789  site-heterogeneous
# 1               Adineta_vaga  -33.1021  site-heterogeneous
# 2    Brachionus_calyciflorus  -19.9037  site-heterogeneous
# 3            Proales_similis  -17.3032  site-heterogeneous
# 4     Hymenolepis_microstoma   31.1503  site-heterogeneous
# ..                       ...       ...                 ...
# 211    Pomphorhynchus_laevis   23.8421    site-homogeneous
# 212          Seison_nebaliae   32.4155    site-homogeneous
# 213  Didymodactylos_carnosus  -28.5791    site-homogeneous
# 214         Rotaria_socialis  -31.1988    site-homogeneous
# 215          Rotaria_sordida  -32.1575    site-homogeneous
#
# [216 rows x 3 columns]

# %%
#LB scores of species full taxon sampling (both models)
fig = plt.figure(figsize=(12,10), tight_layout=True)
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_all_taxa_trees,y=df_lb_all_taxa_trees["Species"],x=df_lb_all_taxa_trees["LB score"],palette="seismic",hue="Model")
plt.xticks(fontsize=12)
plt.xlabel("LB score", fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel("Species", fontsize=14)
plt.rcParams['font.family'] = 'Arial'

plt.savefig("LB_scores_of_species_full_sampling_separate_models.png")
plt.savefig("LB_scores_of_species_full_sampling_separate_models.pdf")
plt.savefig("LB_scores_of_species_full_sampling_separate_models.svg")

# %%
#LB scores of species full taxon sampling (only site-heterogeneous)
df_lb_all_taxa_trees_shet = pd.read_csv("lb_all_species_het_species_values.txt", sep="\t",header=None)
df_lb_all_taxa_trees_shet.columns=["Species","LB score","Model"]

fig = plt.figure(figsize=(10,10))
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_all_taxa_trees_shet,y=df_lb_all_taxa_trees_shet["Species"],x=df_lb_all_taxa_trees_shet["LB score"],palette="RdBu")
#plt.xticks(rotation=90)
plt.xticks(fontsize=12)
plt.xlabel("LB score", fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel("Species", fontsize=14)
plt.savefig("LB_scores_of_species_full_sampling_heterogeneous.png")
plt.savefig("LB_scores_of_species_full_sampling_heterogeneous.pdf")
plt.savefig("LB_scores_of_species_full_sampling_heterogeneous.svg")

# %%
#LB scores of species no platy (including supermatrices with unique site removal strategies)
df_lb_no_platy_trees_shet = pd.read_csv("lb_no_platy_het_species_values.txt", sep="\t",header=None)
df_lb_no_platy_trees_shet.columns=["Species","LB score","Model"]

fig = plt.figure(figsize=(10,10))
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_no_platy_trees_shet,y=df_lb_no_platy_trees_shet["Species"],x=df_lb_no_platy_trees_shet["LB score"],palette="RdBu")
#plt.xticks(rotation=90)
plt.xticks(fontsize=12)
plt.xlabel("LB score", fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel("Species", fontsize=14)
plt.savefig("LB_scores_of_species_no_platy_heterogeneous.png")
plt.savefig("LB_scores_of_species_no_platy_heterogeneous.pdf")
plt.savefig("LB_scores_of_species_no_platy_heterogeneous.svg")

# %%
#LB scores of species no platy (only output supermatrices with unique site removal strategies)
df_lb_no_platy_trees_shet_site_removal_only = pd.read_csv("lb_no_platy_het_species_values_only_site_removal.txt", sep="\t",header=None)
df_lb_no_platy_trees_shet_site_removal_only.columns=["Species","LB score","Model"]

fig = plt.figure(figsize=(12,10), tight_layout=True)
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_no_platy_trees_shet,y=df_lb_no_platy_trees_shet["Species"],x=df_lb_no_platy_trees_shet["LB score"],palette="RdBu")
#plt.xticks(rotation=40)
plt.rcParams['font.family'] = 'Arial'
plt.xticks(fontsize=16)
plt.xlabel("LB score", fontsize=16)
plt.yticks(fontsize=16)
plt.ylabel("Species", fontsize=16)
plt.savefig("LB_scores_of_species_no_platy_heterogeneous.only_site_removal.png")
plt.savefig("LB_scores_of_species_no_platy_heterogeneous.only_site_removal.pdf")
plt.savefig("LB_scores_of_species_no_platy_heterogeneous.only_site_removal.svg")

# %%
#LB scores for species - no platy included - site heterogeneous (exclude supermatrices for which site removal strategies have been applied)
df_lb_no_platy_trees_exclude = pd.read_csv("lb_no_platy_both_models_species_values_siteremoval_datasets_excluded.txt", sep="\t",header=None)
df_lb_no_platy_trees_exclude.columns=["Species","LB score","Model"]

fig = plt.figure(figsize=(12,10), tight_layout=True)
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_no_platy_trees_exclude[df_lb_no_platy_trees_exclude["Model"]=="site-heterogeneous"],y=df_lb_no_platy_trees_exclude["Species"],x=df_lb_no_platy_trees_exclude["LB score"],palette="RdBu")
plt.rcParams['font.family'] = 'Arial'

#plt.xticks(rotation=90)
plt.xticks(fontsize=16)
plt.xlabel("LB score", fontsize=16)
plt.yticks(fontsize=16)
plt.ylabel("Species", fontsize=16)
plt.savefig("LB_scores_of_species_no_platy_heterogeneous_excluded_siteremoval.png")
plt.savefig("LB_scores_of_species_no_platy_heterogeneous_excluded_siteremoval.pdf")
plt.savefig("LB_scores_of_species_no_platy_heterogeneous_excluded_siteremoval.svg")

# %%
#LB scores for species - no platy included - both models (exclude supermatrices for which site removal strategies have been applied)
df_lb_no_platy_trees_exclude = pd.read_csv("lb_no_platy_both_models_species_values_siteremoval_datasets_excluded.txt", sep="\t",header=None)
df_lb_no_platy_trees_exclude.columns=["Species","LB score","Model"]

fig = plt.figure(figsize=(10,10))
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_no_platy_trees_exclude,y=df_lb_no_platy_trees_exclude["Species"],x=df_lb_no_platy_trees_exclude["LB score"],hue="Model",palette="seismic")
#plt.xticks(rotation=90)
plt.xticks(fontsize=12)
plt.xlabel("LB score", fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel("Species", fontsize=14)
plt.savefig("LB_scores_of_species_no_platy_both_models_excluded_siteremoval.png")
plt.savefig("LB_scores_of_species_no_platy_both_models_excluded_siteremoval.pdf")
plt.savefig("LB_scores_of_species_no_platy_both_models_excluded_siteremoval.svg")

# %%
#Gene family-based LB scores for species - best fitting orthofinder alignments 
df_lb_gene_family_best = pd.read_csv("lb_gene_families_all_species_bestfitting.txt", sep="\t",header=None)
df_lb_gene_family_best.columns=["Species","LB score","Model"]

fig = plt.figure(figsize=(10,10))
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_gene_family_best,y=df_lb_gene_family_best["Species"],x=df_lb_gene_family_best["LB score"],palette="coolwarm")
#plt.xticks(rotation=90)
plt.xticks(fontsize=12)
plt.xlabel("LB score", fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel("Species", fontsize=14)
plt.savefig("LB_scores_of_species_gene_families_original_orthofinder_trees_shet.png")
plt.savefig("LB_scores_of_species_gene_families_original_orthofinder_trees_shet.pdf")
plt.savefig("LB_scores_of_species_gene_families_original_orthofinder_trees_shet.svg")

# %%
#Gene family-based LB scores for species - both models orthofinder alignments 
df_lb_gene_family = pd.read_csv("lb_gene_families_all_species_both_models.txt", sep="\t",header=None)
df_lb_gene_family.columns=["Species","LB score","Model"]

fig = plt.figure(figsize=(10,10))
sns.set_style("darkgrid")
sns.boxplot(data=df_lb_gene_family,y=df_lb_gene_family["Species"],x=df_lb_gene_family["LB score"],palette="seismic", hue="Model")
#plt.xticks(rotation=90)
plt.xticks(fontsize=12)
plt.xlabel("LB score", fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel("Species", fontsize=14)
# Out:
# Text(0, 0.5, 'Species')

# %%
#Make plots of trees based on different filtering criteria

# %%
df_supermatrices = pd.read_csv("supermatrices.txt", sep="\t")

# %%
df_supermatrices
# Out:
#        Supermatrix ID  No. of species  No. of genes  No. of alignment sites  \
# 0       supermatrix A              12           345                   86409
# 1       supermatrix B              12           233                   56310
# 2       supermatrix C              12           267                   86214
# 3       supermatrix D              12           262                   79411
# 4       supermatrix E              12          1200                  206917
# 5       supermatrix F              10          1200                  206917
# 6       supermatrix G              10          1200                   65508
# 7       supermatrix H              10          1200                  162015
# 8       supermatrix I              10          1200                  146698
# 9   supermatrix A50.1              12            50                   17007
# 10  supermatrix A50.2              10            50                   17007
# ...

# %%
df_supermatrices.describe()
# Out:
#        No. of species  No. of genes  No. of alignment sites  No. of PI sites  \
# count       21.000000     21.000000               21.000000        21.000000
# mean        10.857143    367.000000            62025.666667     26738.095238
# std          1.014185    485.529505            65158.365354     32532.102551
# min         10.000000     50.000000            12884.000000      3524.000000
# 25%         10.000000     50.000000            17007.000000      5057.000000
# 50%         10.000000     50.000000            22100.000000      7265.000000
# 75%         12.000000    345.000000            86214.000000     38043.000000
# max         12.000000   1200.000000           206917.000000    120319.000000
#
#        Prop. of PI sites  Singleton sites  Prop. of singleton sites  \
# count          21.000000        21.000000                 21.000000
# mean            0.374667     15982.000000                  0.230143
# std             0.094546     19979.600874                  0.068414
# ...

# %%
sns.jointplot(data=df_supermatrices,x="RCFV",y="TORCV")

# %%
sns.jointplot(data=df_supermatrices,x="Average UFB support (site-heterogeneous model)",y="TORCV")

# %%
sns.jointplot(data=df_supermatrices,x="Average UFB support (site-heterogeneous model)",y="No. of alignment sites")

# %%
fig = plt.figure(figsize=(10,10), tight_layout=True)
sns.jointplot(data=df_supermatrices,x="RCFV",y="TORCV", kind="reg", color="purple")
plt.savefig("TORCV_vs_RCFV.png")
plt.savefig("TORCV_vs_RCFV.pdf")
plt.savefig("TORCV_vs_RCFV.svg")

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=df_supermatrices,ylim=(0,1.1),x="No. of alignment sites",y="Prop. of rejected symmetry tests", kind="reg", color="purple")
r, p = stats.pearsonr(x=df_supermatrices["No. of alignment sites"], y=df_supermatrices["Prop. of rejected symmetry tests"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=df_supermatrices["No. of alignment sites"], y=df_supermatrices["Prop. of rejected symmetry tests"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_symmetry_prop.png")
plt.savefig("sites_vs_symmetry_prop.pdf")
plt.savefig("sites_vs_symmetry_prop.svg")
print(ci)
# Out:
# ConfidenceInterval(low=0.5049336079358749, high=0.901438376646776)

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=df_supermatrices,x="No. of alignment sites",y="TORCV", kind="reg", color="purple")
r, p = stats.pearsonr(x=df_supermatrices["No. of alignment sites"], y=df_supermatrices["TORCV"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=df_supermatrices["No. of alignment sites"], y=df_supermatrices["TORCV"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_TORCV.png")
plt.savefig("sites_vs_TORCV.pdf")
plt.savefig("sites_vs_TORCV.svg")
print(ci)
# Out:
# ConfidenceInterval(low=-0.4070233125745591, high=0.4557212450747063)

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=df_supermatrices,x="No. of alignment sites",y="LB score (st. dev.)", kind="reg", color="purple")
r, p = stats.pearsonr(x=df_supermatrices["No. of alignment sites"], y=df_supermatrices["LB score (st. dev.)"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=df_supermatrices["No. of alignment sites"], y=df_supermatrices["LB score (st. dev.)"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_lbstdev.png")
plt.savefig("sites_vs_lbstdev.pdf")
plt.savefig("sites_vs_lbstdev.svg")
print(ci)
# Out:
# ConfidenceInterval(low=-0.22082569566271892, high=0.603994364270252)

# %%
#sns.pairplot(data=df_supermatrices, palette="PuOr")

# %%
#TORCV matrices
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices,y="Supermatrix ID", x="TORCV", hue="No. of species", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("treeness_supermatrices.png")
plt.savefig("treeness_supermatrices.pdf")
plt.savefig("treeness_supermatrices.svg")
#df_supermatrices["TORCV"]

# %%
#LB score for all matrices
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices,y="Supermatrix ID", x="LB score (st. dev.)", hue="No. of species", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("LB score_supermatrices.png")
plt.savefig("LB score_supermatrices.pdf")
plt.savefig("LB score_supermatrices.svg")

# %%
#Treeness over rcv for reduced rtaxon sampling matrices
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices[df_supermatrices["No. of species"]==10],y="Supermatrix ID",hue="No. of genes", x="TORCV", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("treeness_over_rcv_supermatrices_no_platy.png")
plt.savefig("treeness_over_rcv_supermatrices_no_platy.pdf")
plt.savefig("treeness_over_rcv_supermatrices_no_platy.svg")
#df_supermatrices[df_supermatrices["No. species"]==10]

# %%
#TORCV of supermatrices with no Platyhelminthes
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices[df_supermatrices["No. of species"]==10],y="Supermatrix ID", x="TORCV", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("TORCV_supermatrices_no_platy.png")
plt.savefig("TORCV_supermatrices_no_platy.pdf")
plt.savefig("TORCV_supermatrices_no_platy.svg")


df_supermatrices[df_supermatrices["No. of species"]==10]["TORCV"].mean()
# Out:
# 1.5916666666666666

# %%
#LB score of supermatrices with no Platyhelminthes
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices[df_supermatrices["No. of species"]==10],y="Supermatrix ID", x="LB score (st. dev.)", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("LB_score_supermatrices_no_platy.png")
plt.savefig("LB_score_supermatrices_no_platy.pdf")
plt.savefig("LB_score_supermatrices_no_platy.svg")


df_supermatrices[df_supermatrices["No. of species"]==10]["LB score (st. dev.)"].mean()
# Out:
# 26.10258333333333

# %%
#prop. missing data no Platyhelminthes
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices[df_supermatrices["No. of species"]==10],y="Supermatrix ID", x="Prop. of missing data", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("missing_data_rcv_supermatrices_no_platy.png")
plt.savefig("missing_data_rcv_supermatrices_no_platy.pdf")
plt.savefig("missing_data_rcv_supermatrices_no_platy.svg")

#df_supermatrices[df_supermatrices["No. species"]==10]

df_supermatrices[df_supermatrices["No. of species"]==10]["Prop. of missing data"].mean()
# Out:
# 0.11008333333333335

# %%
#Saturation no Platyhelminthes
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices[df_supermatrices["No. of species"]==10],y="Supermatrix ID", x="Saturation score", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("missing_data_supermatrices_no_platy.png")
plt.savefig("missing_data_supermatrices_no_platy.pdf")
plt.savefig("missing_data_supermatrices_no_platy.svg")

#df_supermatrices[df_supermatrices["No. species"]==10]

df_supermatrices[df_supermatrices["No. of species"]==10]["Saturation score"].mean()
# Out:
# 0.6151666666666666

# %%
#PI sites prop no Platyhelminthes
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices[df_supermatrices["No. of species"]==10],y="Supermatrix ID", x="Prop. of PI sites", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("prop_PI_supermatrices_no_platy.png")
plt.savefig("prop_PI_supermatrices_no_platy.pdf")
plt.savefig("prop_PI_supermatrices_no_platy.svg")

#df_supermatrices[df_supermatrices["No. species"]==10]

df_supermatrices[df_supermatrices["No. of species"]==10]["Prop. of PI sites"].mean()
# Out:
# 0.32191666666666663

# %%
#PI sites prop no Platyhelminthes
fig = plt.figure(tight_layout=True, figsize=(10,8))

sns.barplot(data=df_supermatrices[df_supermatrices["No. of species"]==10],y="Supermatrix ID", x="RCFV", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("RCFV_supermatrices_no_platy.png")
plt.savefig("RCFV_supermatrices_no_platy.pdf")
plt.savefig("RCFV_supermatrices_no_platy.svg")

#df_supermatrices[df_supermatrices["No. species"]==10]

df_supermatrices[df_supermatrices["No. of species"]==10]["RCFV"].mean()
# Out:
# 0.04083333333333333

# %%
#Saturation
fig = plt.figure(tight_layout=True, figsize=(10,10))
sns.barplot(data=df_supermatrices,y="Supermatrix ID", x="Saturation score", palette="seismic")
#plt.xticks(rotation=90)
plt.savefig("saturation_supermatrices.png")
plt.savefig("saturation_supermatrices.pdf")
plt.savefig("saturation_supermatrices.svg")

# %%
# Symmetry tests
fig = plt.figure(tight_layout=True, figsize=(10,10))
sns.barplot(data=df_supermatrices,y="Supermatrix ID", x="Prop. of rejected symmetry tests",hue="No. of species", palette="seismic")
#plt.xticks(rotation=90)

plt.savefig("homo_no_species_supermatrices.png")
plt.savefig("homo_no_species_supermatrices.pdf")
plt.savefig("homo_no_species_supermatrices.svg")

# %%
#Symmetry tests
fig = plt.figure(tight_layout=True, figsize=(10,8))
sns.barplot(data=df_supermatrices,y="Supermatrix ID", x="Prop. of rejected symmetry tests", palette="coolwarm")
#plt.xticks(rotation=90)
plt.savefig("homo_supermatrices.png")
plt.savefig("homo_supermatrices.pdf")
plt.savefig("homo_supermatrices.svg")

# %%
sns.jointplot(data=df_supermatrices,x="RCFV",y="Prop. of rejected symmetry tests", kind="reg",color="orange")
plt.savefig("homo_vs_RCFV.png")
plt.savefig("homo_vs_RCFV.pdf")
plt.savefig("homo_vs_RCFV.svg")

# %%
sns.jointplot(data=df_supermatrices,x="TORCV",y="Prop. of rejected symmetry tests", kind="reg",color="orange")

# %%
fig = plt.figure(tight_layout=True, figsize=(10,8))
sns.barplot(data=df_supermatrices,y="Supermatrix ID", x="No. of alignment sites", palette="coolwarm")
#plt.xticks(rotation=90)
plt.savefig("sites_supermatrices.png")
plt.savefig("sites_supermatrices.pdf")
plt.savefig("sites_supermatrices.svg")

# %%
#no platy - site heterogeneous (including matrix H)
df_species_tree_methods = pd.read_csv("species_tree_methods.txt", sep="\t")

# %%
df_species_tree_methods
# Out:
#                                               Dataset      Method  Topology  \
# 0           A. Original orthofinder OG trees (n=2010)        STAG         1
# 1           A. Original orthofinder OG trees (n=2010)  Astral-Pro         1
# 2           A. Original orthofinder OG trees (n=2010)  SpeciesRax         3
# 3           A. Original orthofinder OG trees (n=2010)      MiniNJ         1
# 4   B. OG trees inferred under best-fit model (IQ-...        STAG         1
# 5   B. OG trees inferred under best-fit model (IQ-...  Astral-Pro         1
# 6   B. OG trees inferred under best-fit model (IQ-...  SpeciesRax         1
# 7   B. OG trees inferred under best-fit model (IQ-...      MiniNJ         1
# 8   C. Kept top 50% of OGs from B with the lowest ...        STAG         1
# 9   C. Kept top 50% of OGs from B with the lowest ...  Astral-Pro         1
# 10  C. Kept top 50% of OGs from B with the lowest ...  SpeciesRax         1
# ...

# %%
f = df_species_tree_methods.pivot_table(index="Dataset", columns="Method", values="Topology")

# %%
from matplotlib.colors import ListedColormap
fig = plt.figure(figsize=(14,10), tight_layout=True)
plt.rcParams['font.family'] = 'Arial'
cmap = sns.cubehelix_palette(n_colors=3)
sns.heatmap(f, cmap=ListedColormap(cmap), linewidths = 0.5)
plt.xlabel("Species tree method", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel("Dataset", fontsize=14)
plt.savefig("heatmap.png")
plt.savefig("heatmap.pdf")
plt.savefig("heatmap.svg")

# %%
sns.heatmap(f, cmap="RdBu")
# Out:
# <AxesSubplot:xlabel='Method', ylabel='Dataset'>

# %%
#fig = plt.figure(figsize=(18,20), tight_layout=True)
reduced_columns_df=df_supermatrices[["Supermatrix ID","No. of species","Average UFB support (site-heterogeneous model)","Saturation score", "Average P-distance","Hemirotifera","Pararotatoria","Seisonidea-sister","Lemniscea","No. of alignment sites","TORCV","RCFV","Monophyly of Syndermata (site-homogeneous model)", "Prop. of singleton sites", "Prop. of PI sites","No. of genes", "LB score (st. dev.)","Prop. of rejected symmetry tests", "Monophyly of Syndermata (site-heterogeneous model)"]]
no_platy_reduced_cols_df=reduced_columns_df[reduced_columns_df["No. of species"]==10]
#sns.pairplot(data=new_df)

# %%
sns.jointplot(data=reduced_columns_df,x=reduced_columns_df["Prop. of PI sites"],y=reduced_columns_df["LB score (st. dev.)"], kind="reg")

# %%
sns.jointplot(data=reduced_columns_df,x=reduced_columns_df["Prop. of singleton sites"],y=reduced_columns_df["LB score (st. dev.)"], kind="reg")

# %%
sns.jointplot(data=reduced_columns_df,x=reduced_columns_df["TORCV"],y=reduced_columns_df["LB score (st. dev.)"], kind="reg")

# %%
sns.jointplot(data=reduced_columns_df,x=reduced_columns_df["RCFV"],y=reduced_columns_df["LB score (st. dev.)"], kind="reg")

# %%
sns.jointplot(data=reduced_columns_df,x=reduced_columns_df["TORCV"],xlim=(0,1),y=reduced_columns_df["Prop. of rejected symmetry tests"], kind="reg")

# %%
#Check if supermatix-G is outlier TORCV, Saturation, LB score

fig, axs = plt.subplots(nrows=1,ncols=3, tight_layout=True, figsize=(12,8))

#make boxplots
sns.boxplot(ax=axs[0],data=df_supermatrices,x="No. of species", y="TORCV", boxprops=dict(alpha=.3))
sns.boxplot(ax=axs[1],data=df_supermatrices,x="No. of species", y="Saturation score", boxprops=dict(alpha=.3))
sns.boxplot(ax=axs[2],data=df_supermatrices,x="No. of species", y="LB score (st. dev.)", boxprops=dict(alpha=.3))

#Overlay stripplots
a = sns.stripplot(ax=axs[0],data=df_supermatrices,x="No. of species", y="TORCV", hue="Supermatrix ID",jitter=True)
a.get_legend().remove()
b = sns.stripplot(ax=axs[1],data=df_supermatrices,x="No. of species", y="Saturation score",hue="Supermatrix ID", jitter=True)
b.get_legend().remove()
c =sns.stripplot(ax=axs[2],data=df_supermatrices,x="No. of species", y="LB score (st. dev.)",hue="Supermatrix ID", jitter=True)
c.get_legend().remove()
handles, labels = axs[2].get_legend_handles_labels()

fig.supxlabel("Supermatrices separated by taxon sampling")
fig.legend(handles, labels, loc='right', bbox_to_anchor=(1.15, 0.5))

# %%
#Supermatrix G shows exteme values of TORCV, LB score st.dev. and much lower than the median score for the Saturation. 
#index. It is the matrix with the most conservative removal of amino acid sites. Therefore the conditions under which 
#tested hypotheses are inferred should be checked after removing this supermatrix

# %%
no_platy_reduced_cols_df["TORCV"].median()
# Out:
# 1.2035

# %%
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]=="supermatrix G"]["TORCV"]
# Out:
# 6    4.464
# Name: TORCV, dtype: float64

# %%
no_platy_reduced_cols_df["Saturation score"].median()
# Out:
# 0.7565

# %%
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]=="supermatrix G"]["Saturation score"]
# Out:
# 6    0.471
# Name: Saturation score, dtype: float64

# %%
no_platy_reduced_cols_df["LB score (st. dev.)"].median()
# Out:
# 25.0275

# %%
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]=="supermatrix G"]["LB score (st. dev.)"]
# Out:
# 6    15.466
# Name: LB score (st. dev.), dtype: float64

# %%
#Make stripplot
fig, axs = plt.subplots(nrows=1,ncols=3, tight_layout=True)

sns.stripplot(ax=axs[0],data=no_platy_reduced_cols_df,y="TORCV",hue="Supermatrix ID", jitter=True)
sns.stripplot(ax=axs[1],data=no_platy_reduced_cols_df,y="Saturation score", jitter=True)
sns.stripplot(ax=axs[2],data=no_platy_reduced_cols_df,y="LB score (st. dev.)", jitter=True)

fig.supxlabel("Supermatrices without Platyhelminthes")
# Out:
# Text(0.5, 0.01, 'Supermatrices without Platyhelminthes')

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=no_platy_reduced_cols_df,x="No. of alignment sites",y="TORCV", kind="reg", color="purple")
r, p = stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["TORCV"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["TORCV"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_TORCV_no_platy.png")
plt.savefig("sites_vs_TORCV_no_platy.pdf")
plt.savefig("sites_vs_TORCV_no_platy.svg")
print(ci)
# Out:
# ConfidenceInterval(low=-0.5328494221365955, high=0.6122587862135928)

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=no_platy_reduced_cols_df,x="No. of alignment sites",y="LB score (st. dev.)", kind="reg", color="purple")
r, p = stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["LB score (st. dev.)"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["LB score (st. dev.)"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_lb_scorestdev_no_platy.png")
plt.savefig("sites_vs_lb_scorestdev_no_platy.pdf")
plt.savefig("sites_vs_lb_scorestdev_no_platy.svg")
print(ci)
# Out:
# ConfidenceInterval(low=-0.3637229940231622, high=0.728476175965922)

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=no_platy_reduced_cols_df,ylim=(0,1.1),x="No. of alignment sites",y="Prop. of rejected symmetry tests", kind="reg", color="purple")
r, p = stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["Prop. of rejected symmetry tests"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["Prop. of rejected symmetry tests"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_symmetryprop_no_platy.png")
plt.savefig("sites_vs_symmetryprop_no_platy.pdf")
plt.savefig("sites_vs_symmetryprop_no_platy.svg")
print(ci)
# Out:
# ConfidenceInterval(low=0.47952986126904706, high=0.9497297426627254)

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=no_platy_reduced_cols_df,ylim=(0,1.1),x="No. of alignment sites",y="Prop. of PI sites", kind="reg", color="purple")
r, p = stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["Prop. of PI sites"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["Prop. of PI sites"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_PI_no_platy.png")
plt.savefig("sites_vs_PI_no_platy.pdf")
plt.savefig("sites_vs_PI_no_platy.svg")
print(ci)
# Out:
# ConfidenceInterval(low=0.2121291218520109, high=0.909052924156347)

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(10,10), tight_layout=True)
f = sns.jointplot(data=no_platy_reduced_cols_df,ylim=(0,1.1),x="No. of alignment sites",y="Prop. of PI sites", kind="reg", color="purple")
r, p = stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["Prop. of PI sites"])
phantom, = f.ax_joint.plot([], [], linestyle="", alpha=0)
ci =stats.pearsonr(x=no_platy_reduced_cols_df["No. of alignment sites"], y=no_platy_reduced_cols_df["Prop. of PI sites"]).confidence_interval()
f.ax_joint.legend([phantom],['Pearson r: r={:5.5f}, p={:5.5f}'.format(r,p)])

plt.savefig("sites_vs_PI_no_platy.png")
plt.savefig("sites_vs_PI_no_platy.pdf")
plt.savefig("sites_vs_PI_no_platy.svg")
print(ci)
# Out:
# ConfidenceInterval(low=0.2121291218520109, high=0.909052924156347)

# %%
#Check support for tested hypotheses based on LB score and TORCV score

# %%
#Lemniscea support datasets without Platyhelminthes and without supermatrix G
fig = plt.figure(tight_layout=True, figsize=(10,10))
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Lemniscea", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Lemniscea", title_fontsize=14,fontsize=14)

plt.ylabel("LB score (st. dev.)", fontsize=14)
plt.savefig("lb_score_TORCV_Lemniscea_no_platy.excluded_supermatrix_G.png")
plt.savefig("lb_score_TORCV_Lemniscea_no_platy.excluded_supermatrix_G.pdf")
plt.savefig("lb_score_TORCV_Lemniscea_no_platy.excluded_supermatrix_G.svg")

# %%
#Lemniscea support datasets without Platyhelminthes
fig = plt.figure(tight_layout=True)
joint = sns.jointplot(data=no_platy_reduced_cols_df, x=no_platy_reduced_cols_df["TORCV"], y=no_platy_reduced_cols_df["LB score (st. dev.)"], hue="Lemniscea", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Lemniscea", title_fontsize=14,fontsize=14)


plt.savefig("lb_score_TORCV_Lemniscea_no_platy.png")
plt.savefig("lb_score_TORCV_Lemniscea_no_platy.pdf")
plt.savefig("lb_score_TORCV_Lemniscea_no_platy.svg")

# %%
#Lemniscea support datasets all species (excluded supermatrix G)
fig = plt.figure(tight_layout=True)
df_selected=reduced_columns_df[reduced_columns_df["Supermatrix ID"]!="supermatrix G"]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Lemniscea", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Lemniscea", title_fontsize=14,fontsize=14)



plt.savefig("lb_score_TORCV_Lemniscea_all.excluded_G.png")
plt.savefig("lb_score_TORCV_Lemniscea_all.excluded_G.pdf")
plt.savefig("lb_score_TORCV_Lemniscea_all.excluded_G.svg")

# %%
#Lemniscea support datasets all species
fig = plt.figure(tight_layout=True)
joint = sns.jointplot(data=reduced_columns_df, x=reduced_columns_df["TORCV"], y=reduced_columns_df["LB score (st. dev.)"], hue="Lemniscea", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Lemniscea", title_fontsize=14,fontsize=14)

plt.savefig("lb_score_TORCV_Lemniscea_all.png")
plt.savefig("lb_score_TORCV_Lemniscea_all.pdf")
plt.savefig("lb_score_TORCV_Lemniscea_all.svg")

# %%
#Mean TORCV score of datasets supporting Lemniscea (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Lemniscea"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].mean()
# Out:
# 1.0758333333333334

# %%
#Mean TORCV score of datasets not supporting Lemniscea (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Lemniscea"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].mean()
# Out:
# 1.6362

# %%
#Mean Lb score of datasets supporting Lemniscea (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Lemniscea"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["LB score (st. dev.)"].mean()
# Out:
# 29.741333333333333

# %%
#Mean Lb score of datasets not supporting Lemniscea (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Lemniscea"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["LB score (st. dev.)"].mean()
# Out:
# 23.8634

# %%
#Median TORCV score of datasets supporting Lemniscea (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==1]["TORCV"].median()
# Out:
# 1.002

# %%
#Median TORCV score of datasets not supporting Lemniscea (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==0]["TORCV"].median()
# Out:
# 1.6015

# %%
#Median Lb score score of datasets supporting Lemniscea (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==1]["LB score (st. dev.)"].median()
# Out:
# 32.849999999999994

# %%
#Median Lb score score of datasets not supporting Lemniscea (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==0]["LB score (st. dev.)"].median()
# Out:
# 21.9185

# %%
#Median Saturation score score of datasets supporting Lemniscea (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==1]["Saturation score"].median()
# Out:
# 0.7575000000000001

# %%
#Median Saturation score score of datasets not supporting Lemniscea (datasets without Platyhelminthes)(excluded supermatrix C50.1)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==0]["Saturation score"].median()
# Out:
# 0.694

# %%
#Median RCFV score of datasets supporting Lemniscea (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==1]["RCFV"].median()
# Out:
# 0.035500000000000004

# %%
#Median RCFV score of datasets not supporting Lemniscea (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Lemniscea"]==0]["RCFV"].median()
# Out:
# 0.037

# %%
#Make barplots of median values for lb score st; saturation score and TORCV depending on whether Lemniscea was inferred (only 
# supermatrices without (Platyhelminthes)
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Lemniscea", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
#third subplot     
sns.barplot(ax=axs[2], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Lemniscea", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets that support or not (1,0) monophyletic Lemniscea", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Lemniscea_barplots.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Lemniscea_barplots.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Lemniscea_barplots.svg")
#no_platy_reduced_cols_df

# %%
#Make barplots of median values for lb score st and TORCV depending on whether Lemniscea was inferred (only 
# supermatrices without (Platyhelminthes)
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Lemniscea", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets that support or not (1,0) monophyletic Lemniscea", fontsize=16)        
fig.savefig("lb_score_TORCV_median_Lemniscea_barplots.png")
fig.savefig("lb_score_TORCV_median_Lemniscea_barplots.pdf")
fig.savefig("lb_score_TORCV_median_Lemniscea_barplots.svg")

# %%
#Make barplots of median values for lb score st; saturation score and TORCV depending on whether Lemniscea was inferred (only 
#supermatrices without (Platyhelminthes) and without supermatrix G

fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Lemniscea", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.barplot(ax=axs[2], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Lemniscea", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets that support or not (1,0) monophyletic Lemniscea", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Lemniscea_barplots.excluded_G.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Lemniscea_barplots.excluded_G.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Lemniscea_barplots.excluded_G.svg")

# %%
#Make barplots of median values for lb score st and TORCV depending on whether Lemniscea was inferred (only 
#supermatrices without (Platyhelminthes) and without supermatrix G

fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Lemniscea", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
fig.supxlabel("Datasets that support or not (1,0) monophyletic Lemniscea", fontsize=16)
fig.savefig("lb_score_TORCV_median_Lemniscea_barplots.excluded_G.png")
fig.savefig("lb_score_TORCV_median_Lemniscea_barplots.excluded_G.pdf")
fig.savefig("lb_score_TORCV_median_Lemniscea_barplots.excluded_G.svg")

# %%
#Pararotatoria support datasets without Platyhelminthes (excluded matrix G)
fig = plt.figure(tight_layout=True)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Pararotatoria", kind="scatter", palette="seismic")

#sns.jointplot returns a JointGrid object, which gives you access to the matplotlib axes and you can then manipulate from there.
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
joint.ax_joint.legend(title="Pararotatoria", title_fontsize=14,fontsize=14)

plt.savefig("lb_score_TORCV_Pararotatoria_no_platy.excluded_G.png")
plt.savefig("lb_score_TORCV_Pararotatoria_no_platy.excluded_G.pdf")
plt.savefig("lb_score_TORCV_Pararotatoria_no_platy.excluded_G.svg")

# %%
#Pararotatoria support datasets without Platyhelminthes
fig = plt.figure(tight_layout=True)
joint = sns.jointplot(data=no_platy_reduced_cols_df, x=no_platy_reduced_cols_df["TORCV"], y=no_platy_reduced_cols_df["LB score (st. dev.)"], hue="Pararotatoria", kind="scatter", palette="seismic")

joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
joint.ax_joint.legend(title="Pararotatoria", title_fontsize=14,fontsize=14)


plt.savefig("lb_score_TORCV_Pararotatoria_no_platy.png")
plt.savefig("lb_score_TORCV_Pararotatoria_no_platy.pdf")
plt.savefig("lb_score_TORCV_Pararotatoria_no_platy.svg")

# %%
#Pararotatoria support datasets all species (excluded supermatrix G)
fig = plt.figure(tight_layout=True)
df_selected=reduced_columns_df[reduced_columns_df["Supermatrix ID"]!="supermatrix G"]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Pararotatoria", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Pararotatoria", title_fontsize=14,fontsize=14)


plt.savefig("lb_score_TORCV_Pararotatoria_all.excluded_G.png")
plt.savefig("lb_score_TORCV_Pararotatoria_all.excluded_G.pdf")
plt.savefig("lb_score_TORCV_Pararotatoria_all.excluded_G.svg")

# %%
#Pararotatoria support datasets all species
fig = plt.figure(tight_layout=True)
joint = sns.jointplot(data=reduced_columns_df, x=reduced_columns_df["TORCV"], y=reduced_columns_df["LB score (st. dev.)"], hue="Pararotatoria", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Pararotatoria", title_fontsize=14,fontsize=14)



plt.savefig("lb_score_TORCV_Pararotatoria_all.png")
plt.savefig("lb_score_TORCV_Pararotatoria_all.pdf")
plt.savefig("lb_score_TORCV_Pararotatoria_all.svg")

# %%
#Mean TORCV score of datasets supporting Pararotatoria (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Pararotatoria"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].mean()
# Out:
# 1.6362

# %%
#Mean TORCV score of datasets not supporting Pararotatoria (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Pararotatoria"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].mean()
# Out:
# 1.0758333333333334

# %%
#Mean Lb score of datasets supporting Pararotatoria (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Pararotatoria"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["LB score (st. dev.)"].mean()
# Out:
# 23.8634

# %%
#Mean Lb score of datasets not supporting Pararotatoria (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Pararotatoria"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["LB score (st. dev.)"].mean()
# Out:
# 29.741333333333333

# %%
#Median TORCV score of datasets supporting Pararotatoria (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==1]["TORCV"].median()
# Out:
# 1.6015

# %%
#Median TORCV score of datasets not supporting Pararotatoria (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==0]["TORCV"].median()
# Out:
# 1.002

# %%
#Median Lb score score of datasets supporting Pararotatoria (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==1]["LB score (st. dev.)"].median()
# Out:
# 21.9185

# %%
#Median Lb score score of datasets not supporting Pararotatoria (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==0]["LB score (st. dev.)"].median()
# Out:
# 32.849999999999994

# %%
#Median Saturation score score of datasets supporting Pararotatoria (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==1]["Saturation score"].median()
# Out:
# 0.694

# %%
#Median Saturation score score of datasets not supporting Pararotatoria (datasets without Platyhelminthes)(excluded supermatrix C50.1)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==0]["Saturation score"].median()
# Out:
# 0.7575000000000001

# %%
#Median RCFV score of datasets supporting Pararotatoria (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==1]["RCFV"].median()
# Out:
# 0.037

# %%
#Median RCFV score of datasets not supporting Pararotatoria (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Pararotatoria"]==0]["RCFV"].median()
# Out:
# 0.035500000000000004

# %%
#Barplots ls score, TORCV, saturation for Pararotatoria (datasets without Platyhelminthes)
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Pararotatoria", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Pararotatoria", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
#third subplot     
sns.barplot(ax=axs[2], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Pararotatoria", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets that support or not (1,0) monophyletic Pararotatoria", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Pararotatoria_barplots.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Pararotatoria_barplots.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Pararotatoria_barplots.svg")

# %%
#Barplots ls score, TORCV for Pararotatoria (datasets without Platyhelminthes)
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Pararotatoria", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Pararotatoria", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets that support or not (1,0) monophyletic Pararotatoria", fontsize=16)        
fig.savefig("lb_score_TORCV_median_Pararotatoria_barplots.png")
fig.savefig("lb_score_TORCV_median_Pararotatoria_barplots.pdf")
fig.savefig("lb_score_TORCV_median_Pararotatoria_barplots.svg")

# %%
#Barplots lb score, TORCV, saturation for Pararotatoria (datasets without Platyhelminthes) - exclude supermatrix G

fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)

df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Pararotatoria", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Pararotatoria", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.barplot(ax=axs[2], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Pararotatoria", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets that support or not (1,0) monophyletic Pararotatoria", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Pararotatoria_barplots.exclude_G.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Pararotatoria_barplots.exclude_G.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Pararotatoria_barplots.exclude_G.svg")

# %%
#Barplots lb score, TORCV for Pararotatoria (datasets without Platyhelminthes) - exclude G

fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Pararotatoria", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Pararotatoria", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
fig.supxlabel("Datasets that support or not (1,0) monophyletic Pararotatoria", fontsize=16)
fig.savefig("lb_score_TORCV_median_Pararotatoria_barplots.exclude_G.png")
fig.savefig("lb_score_TORCV_median_Pararotatoria_barplots.exclude_G.pdf")
fig.savefig("lb_score_TORCV_median_Pararotatoria_barplots.exclude_G.svg")

# %%
#Hemirotifera support datasets without Platyhelminthes (excluded matrix G)
fig = plt.figure(tight_layout=True)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Hemirotifera", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Hemirotifera", title_fontsize=14,fontsize=14)


plt.savefig("lb_score_TORCV_Hemirotifera_no_platy.excluded_G.png")
plt.savefig("lb_score_TORCV_Hemirotifera_no_platy.excluded_G.pdf")
plt.savefig("lb_score_TORCV_Hemirotifera_no_platy.excluded_G.svg")

# %%
#Hemirotifera support datasets without Platyhelminthes
fig = plt.figure(tight_layout=True)
joint = sns.jointplot(data=no_platy_reduced_cols_df, x=no_platy_reduced_cols_df["TORCV"], y=no_platy_reduced_cols_df["LB score (st. dev.)"], hue="Hemirotifera", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Hemirotifera", title_fontsize=14,fontsize=14)

plt.savefig("lb_score_TORCV_Hemirotifera_no_platy.png")
plt.savefig("lb_score_TORCV_Hemirotifera_no_platy.pdf")
plt.savefig("lb_score_TORCV_Hemirotifera_no_platy.svg")

# %%
#Hemirotifera support datasets all species (supermatrix G excluded)
fig = plt.figure(tight_layout=True)
df_selected=reduced_columns_df[reduced_columns_df["Supermatrix ID"]!="supermatrix G"]
sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Hemirotifera", kind="scatter", palette="seismic")

# %%
#Hemirotifera support datasets all species 
fig = plt.figure(tight_layout=True)
joint = sns.jointplot(data=reduced_columns_df, x=reduced_columns_df["TORCV"], y=reduced_columns_df["LB score (st. dev.)"], hue="Hemirotifera", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Hemirotifera", title_fontsize=14,fontsize=14)

plt.savefig("lb_score_TORCV_Hemirotifera_all.png")
plt.savefig("lb_score_TORCV_Hemirotifera_all.pdf")
plt.savefig("lb_score_TORCV_Hemirotifera_all.svg")

# %%
#Mean TORCV score of datasets supporting Hemirotifera (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Hemirotifera"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].mean()
# Out:
# 1.6136000000000004

# %%
#Mean TORCV of datasets not supporting Hemirotifera (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Hemirotifera"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].mean()
# Out:
# 1.0946666666666667

# %%
#Mean Lb score st. dev. of datasets supporting Hemirotifera (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Hemirotifera"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["LB score (st. dev.)"].mean()
# Out:
# 26.544000000000004

# %%
#Mean Lb score st. dev. of datasets not supporting Hemirotifera (datasets without Platyhelminthes) (excluded outlier supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Hemirotifera"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["LB score (st. dev.)"].mean()
# Out:
# 27.507499999999997

# %%
#Median TORCV score of datasets supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Hemirotifera"]==1]["TORCV"].median()
# Out:
# 1.541

# %%
#Median TORCV score of datasets not supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Hemirotifera"]==0]["TORCV"].median()
# Out:
# 1.167

# %%
#Median Lb score of datasets supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Hemirotifera"]==1]["LB score (st. dev.)"].median()
# Out:
# 24.062

# %%
#Median Lb score of datasets not supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Hemirotifera"]==0]["LB score (st. dev.)"].median()
# Out:
# 25.993

# %%
#Median saturation score of datasets supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Hemirotifera"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["Saturation score"].median()
# Out:
# 0.796

# %%
#Median saturation score of datasets not supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Hemirotifera"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["Saturation score"].median()
# Out:
# 0.6565

# %%
#Median saturation score of datasets supporting Hemirotifera (all matrices)
reduced_columns_df[reduced_columns_df["Hemirotifera"]==1]["Saturation score"].median()
# Out:
# 0.796

# %%
#Median saturation score of datasets not supporting Hemirotifera (all matrices)
reduced_columns_df[reduced_columns_df["Hemirotifera"]==0]["Saturation score"].median()
# Out:
# 0.746

# %%
#Median RCFV score of datasets supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Hemirotifera"]==1]["RCFV"].median()
# Out:
# 0.06

# %%
#Median RCFV score of datasets not supporting Hemirotifera (datasets without Platyhelminthes)
no_platy_reduced_cols_df[no_platy_reduced_cols_df["Hemirotifera"]==0]["RCFV"].median()
# Out:
# 0.035

# %%
#barplots of median lb score, TORCV, saturation for Hemirotifera (datasets without Platyhelminthes)

fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Hemirotifera", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Hemirotifera", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
#third subplot     
sns.barplot(ax=axs[2], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
fig.supxlabel("Datasets that support or not (1,0) monophyletic Hemirotifera", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Hemirotifera_barplots.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Hemirotifera_barplots.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Hemirotifera_barplots.svg")

# %%
#barplots of median lb score, TORCV for Hemirotifera (datasets without Platyhelminthes)

fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Hemirotifera", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Hemirotifera", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
fig.supxlabel("Datasets that support or not (1,0) monophyletic Hemirotifera", fontsize=16)
fig.savefig("lb_score_TORCV_median_Hemirotifera_barplots.png")
fig.savefig("lb_score_TORCV_median_Hemirotifera_barplots.pdf")
fig.savefig("lb_score_TORCV_median_Hemirotifera_barplots.svg")

# %%
#barplots of median lb score, TORCV, saturation for Hemirotifera (no Platyhelminthes and no supermatrix G)

df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Hemirotifera", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Hemirotifera", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.barplot(ax=axs[2], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
    
fig.supxlabel("Datasets that support or not (1,0) monophyletic Hemirotifera", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Hemirotifera_barplots.exclude_G.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Hemirotifera_barplots.exclude_G.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Hemirotifera_barplots.exclude_G.svg")

# %%
#barplots of median lb score, TORCV for Hemirotifera (no Platyhelminthes and no supermatrix G)

df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Hemirotifera", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Hemirotifera", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
    
fig.supxlabel("Datasets that support or not (1,0) monophyletic Hemirotifera", fontsize=16)
fig.savefig("lb_score_TORCV_median_Hemirotifera_barplots.exclude_G.png")
fig.savefig("lb_score_TORCV_median_Hemirotifera_barplots.exclude_G.pdf")
fig.savefig("lb_score_TORCV_median_Hemirotifera_barplots.exclude_G.svg")

# %%
#Support for monophyly of all syndermatan groups except Seisonidea - No Platyhelminthes (dataset C50.1 that supports non-monophyletic Syndermata is excluded, also G)
fig = plt.figure(tight_layout=True)
df_selected=no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G") & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix C50.1")]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Seisonidea-sister", kind="scatter", palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Seisonidea-sister", title_fontsize=14,fontsize=14)


plt.savefig("lb_score_TORCV_Seisonidea_sister_no_platy.excluded-C50.1_G.png")
plt.savefig("lb_score_TORCV_Seisonidea_sister_no_platy.excluded-C50.1_G.pdf")
plt.savefig("lb_score_TORCV_Seisonidea_sister_no_platy.excluded-C50.1_G.svg")

# %%
#Support for monophyly of all syndermatan groups except Seisonidea (dataset C50.1 that supports non-monophyletic Syndermata is excluded)
fig = plt.figure(tight_layout=True)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix C50.1"]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Seisonidea-sister", kind="scatter",palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Seisonidea-sister", title_fontsize=14,fontsize=14)


plt.savefig("lb_score_TORCV_Seisonidea_sister_no_platy.png")
plt.savefig("lb_score_TORCV_Seisonidea_sister_no_platy.pdf")
plt.savefig("lb_score_TORCV_Seisonidea_sister_no_platy.svg")

# %%
#Support for monophyly of all syndermatan groups except Seisonidea - all datasets (dataset C50.1 that supports non-monophyletic Syndermata is excluded, also G)
fig = plt.figure(tight_layout=True)
df_selected=reduced_columns_df[(reduced_columns_df["Supermatrix ID"]!="supermatrix G") & (reduced_columns_df["Supermatrix ID"]!="supermatrix C50.1")]
joint= sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Seisonidea-sister", kind="scatter",palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Seisonidea-sister", title_fontsize=14,fontsize=14)

plt.savefig("lb_score_TORCV_Seisonidea_sister_all.exclude_G.png")
plt.savefig("lb_score_TORCV_Seisonidea_sister_all.exclude_G.pdf")
plt.savefig("lb_score_TORCV_Seisonidea_sister_all.exclude_G.svg")

# %%
#Support for monophyly of all syndermatan groups except Seisonidea - all datasets (dataset C50.1 that supports non-monophyletic Syndermata is excluded)
fig = plt.figure(tight_layout=True)
df_selected=reduced_columns_df[reduced_columns_df["Supermatrix ID"]!="supermatrix C50.1"]
joint = sns.jointplot(data=df_selected, x=df_selected["TORCV"], y=df_selected["LB score (st. dev.)"], hue="Seisonidea-sister", kind="scatter",palette="seismic")

#set axes labels and fontsizes
joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#set legend and fontsize
joint.ax_joint.legend(title="Seisonidea-sister", title_fontsize=14,fontsize=14)


plt.savefig("lb_score_TORCV_Seisonidea_sister_all.png")
plt.savefig("lb_score_TORCV_Seisonidea_sister_all.pdf")
plt.savefig("lb_score_TORCV_Seisonidea_sister_all.svg")

# %%
#Mean TORCV score of datasets supporting Seisonidea-sister (datasets without Platyhelminthes) (excluded outlier supermatrix G and C50.1)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G") & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix C50.1")]["TORCV"].mean()
# Out:
# 0.86

# %%
#Mean TORCV score of datasets not supporting Seisonidea-sister (datasets without Platyhelminthes) (excluded outlier supermatrix G and C50.1)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G") & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix C50.1")]["TORCV"].mean()
# Out:
# 1.5994285714285716

# %%
#Mean Lb score of datasets supporting Seisonidea-sister (datasets without Platyhelminthes) (excluded outlier supermatrix G and C50.1)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G") & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix C50.1")]["LB score (st. dev.)"].mean()
# Out:
# 27.649749999999997

# %%
#Mean Lb score of datasets not supporting Seisonidea-sister (datasets without Platyhelminthes) (excluded outlier supermatrix G and C50.1)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["LB score (st. dev.)"].mean()
# Out:
# 26.738

# %%
#Median TORCV score of datasets supporting Seisonidea-sister (datasets without Platyhelminthes
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].median()
# Out:
# 0.858

# %%
#Median TORCV score of datasets not supporting Seisonidea-sister (datasets without Platyhelminthes)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["TORCV"].median()
# Out:
# 1.541

# %%
#Median Lb score score of datasets supporting Seisonidea-sister (datasets without Platyhelminthes)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix C50.1")]["LB score (st. dev.)"].median()
# Out:
# 29.381

# %%
#Median Saturation score score of datasets supporting Seisonidea-sister (datasets without Platyhelminthes)(excluded supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==1)& (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G")]["Saturation score"].median()
# Out:
# 0.5765

# %%
#Median Saturation score score of datasets not supporting Seisonidea-sister (datasets without Platyhelminthes)(excluded supermatrix G)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G") ]["Saturation score"].median()
# Out:
# 0.796

# %%
#Median RCFV score of datasets supporting Seisonidea-sister (datasets without Platyhelminthes)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==1) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G") ]["RCFV"].median()
# Out:
# 0.5765

# %%
#Median RCFV score of datasets not supporting Seisonidea-sister (datasets without Platyhelminthes)
no_platy_reduced_cols_df[(no_platy_reduced_cols_df["Seisonidea-sister"]==0) & (no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G") ]["RCFV"].median()
# Out:
# 0.037

# %%
#Make one plot for all properties Seisonidea-sister

# %%
#Barplots of median lb score, TORCV, saturation for monophyly of all groups except Seisonidea (Seisonidea-sister hypothesis)
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Seisonidea-sister", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Seisonidea-sister", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
#third subplot     
sns.barplot(ax=axs[2], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Seisonidea-sister", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
fig.supxlabel("Datasets supporting or not (1,0) monophyletic Syndermata except Seisonidea (Seisonidea-sister hypothesis)", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Seisonidea_sister_barplots.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Seisonidea_sister_barplots.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Seisonidea_sister_barplots.svg")

# %%
#Barplots of median lb score and TORCV for monophyly of all groups except Seisonidea (Seisonidea-sister hypothesis)
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)

#First subplot
sns.barplot(ax=axs[0], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Seisonidea-sister", palette="seismic")
#remove xlabel for individual subplot
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

#Second subplot
sns.barplot(ax=axs[1], estimator=np.median, data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Seisonidea-sister", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
fig.supxlabel("Datasets supporting or not (1,0) monophyletic Syndermata except Seisonidea (Seisonidea-sister hypothesis)", fontsize=16)
fig.savefig("lb_score_TORCV_median_Seisonidea_sister_barplots.png")
fig.savefig("lb_score_TORCV_median_Seisonidea_sister_barplots.pdf")
fig.savefig("lb_score_TORCV_median_Seisonidea_sister_barplots.svg")

# %%
#Barplots of median lb score, TORCV, saturation for monophyly of all groups except Seisonidea (Seisonidea-sister hypothesis)
#excluded supermatrix G

df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=3, tight_layout=True)

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Seisonidea-sister", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.barplot(ax=axs[2], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Seisonidea-sister", palette="seismic")
axs[2].set_xlabel("")
axs[2].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0) monophyletic Syndermata except Seisonidea (Seisonidea-sister hypothesis)", fontsize=16)
fig.savefig("lb_score_TORCV_satscoreMedian_Seisonidea_sister_barplots.exclude_G.png")
fig.savefig("lb_score_TORCV_satscoreMedian_Seisonidea_sister_barplots.exclude_G.pdf")
fig.savefig("lb_score_TORCV_satscoreMedian_Seisonidea_sister_barplots.exclude_G.svg")

# %%
#Barplots of median lb score and TORCV for monophyly of all groups except Seisonidea (Seisonidea-sister hypothesis)
#excluded supermatrix G

df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=2, tight_layout=True)

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["LB score (st. dev.)"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("")
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["TORCV"], x="Seisonidea-sister", palette="seismic")
axs[1].set_xlabel("")
axs[1].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0) monophyletic Syndermata except Seisonidea (Seisonidea-sister hypothesis)", fontsize=16)
fig.savefig("lb_score_TORCV_median_Seisonidea_sister_barplots.exclude_G.png")
fig.savefig("lb_score_TORCV_median_Seisonidea_sister_barplots.exclude_G.pdf")
fig.savefig("lb_score_TORCV_median_Seisonidea_sister_barplots.exclude_G.svg")

# %%
#plot saturation median barplots for datasets of different hypotheses with supermatrix G excluded

# %%
#plot saturation median barplots for datasets of different hypotheses with supermatrix G excluded
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.barplot(ax=axs[2], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.barplot(ax=axs[3], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("satscore_median_all_hypotheses_barplots.exclude_G.png")
fig.savefig("satscore_median_all_hypotheses_barplots.exclude_G.pdf")
fig.savefig("satscore_median_all_hypotheses_barplots.exclude_G.svg")

# %%
df_selected=no_platy_reduced_cols_df
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.barplot(ax=axs[0], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.barplot(ax=axs[1], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.barplot(ax=axs[2], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.barplot(ax=axs[3], estimator=np.median, data=df_selected, y=df_selected["Saturation score"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("satscore_median_all_hypotheses_barplots.png")
fig.savefig("satscore_median_all_hypotheses_barplots.pdf")
fig.savefig("satscore_median_all_hypotheses_barplots.svg")

# %%
#Boxplots Saturation score (excluded G)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=df_selected, y=df_selected["Saturation score"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=df_selected, y=df_selected["Saturation score"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=df_selected, y=df_selected["Saturation score"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=df_selected, y=df_selected["Saturation score"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("satscore_median_all_hypotheses_boxplots.exclude_G.png")
fig.savefig("satscore_median_all_hypotheses_boxplots.exclude_G.pdf")
fig.savefig("satscore_median_all_hypotheses_boxplots.exclude_G.svg")

# %%
#Boxplots Saturation score
df_selected=no_platy_reduced_cols_df
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=df_selected, y=df_selected["Saturation score"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=df_selected, y=df_selected["Saturation score"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=df_selected, y=df_selected["Saturation score"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=df_selected, y=df_selected["Saturation score"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("satscore_median_all_hypotheses_boxplots.png")
fig.savefig("satscore_median_all_hypotheses_boxplots.pdf")
fig.savefig("satscore_median_all_hypotheses_boxplots.svg")

# %%
#Boxplots TORCV (excluded G)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=df_selected, y=df_selected["TORCV"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=df_selected, y=df_selected["TORCV"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=df_selected, y=df_selected["TORCV"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=df_selected, y=df_selected["TORCV"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("TORCV_median_all_hypotheses_boxplots.exclude_G.png")
fig.savefig("TORCV_median_all_hypotheses_boxplots.exclude_G.pdf")
fig.savefig("TORCV_median_all_hypotheses_boxplots.exclude_G.svg")

# %%
#Boxplots TORCV
df_selected=no_platy_reduced_cols_df
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=df_selected, y=df_selected["TORCV"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=df_selected, y=df_selected["TORCV"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=df_selected, y=df_selected["TORCV"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=df_selected, y=df_selected["TORCV"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("TORCV_median_all_hypotheses_boxplots.png")
fig.savefig("TORCV_median_all_hypotheses_boxplots.pdf")
fig.savefig("TORCV_median_all_hypotheses_boxplots.svg")

# %%
#Boxplots lb scores (excluded G)
df_selected=no_platy_reduced_cols_df[no_platy_reduced_cols_df["Supermatrix ID"]!="supermatrix G"]
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("LB score_median_all_hypotheses_boxplots.exclude_G.png")
fig.savefig("LB score_median_all_hypotheses_boxplots.exclude_G.pdf")
fig.savefig("LB score_median_all_hypotheses_boxplots.exclude_G.svg")

# %%
#Boxplots lb scores
df_selected=no_platy_reduced_cols_df
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=df_selected, y=df_selected["LB score (st. dev.)"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("LB score_median_all_hypotheses_boxplots.png")
fig.savefig("LB score_median_all_hypotheses_boxplots.pdf")
fig.savefig("LB score_median_all_hypotheses_boxplots.svg")

# %%
#Boxplots Saturation score
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("Saturation score", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["Saturation score"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("satscore_median_all_hypotheses_boxplots.png")
fig.savefig("satscore_median_all_hypotheses_boxplots.pdf")
fig.savefig("satscore_median_all_hypotheses_boxplots.svg")

# %%
#Boxplots TORCV
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("TORCV", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["TORCV"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("TORCV_median_all_hypotheses_boxplots.png")
fig.savefig("TORCV_median_all_hypotheses_boxplots.pdf")
fig.savefig("TORCV_median_all_hypotheses_boxplots.svg")

# %%
#Boxplots lb score
fig, axs = plt.subplots(figsize=(12,6), nrows=1, ncols=4, tight_layout=True, sharey=True)

sns.boxplot(ax=axs[0], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Seisonidea-sister", palette="seismic")
axs[0].set_xlabel("Seisonidea-sister hypothesis",  fontsize=12)
axs[0].set_ylabel("LB score (st. dev.)", fontsize=14)
#Increase size of tick labels
for tick in axs[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)


sns.boxplot(ax=axs[1], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Lemniscea", palette="seismic")
axs[1].set_xlabel("Lemniscea hypothesis", fontsize=12)
axs[1].set_ylabel("")
#Increase size of tick labels
for tick in axs[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        

sns.boxplot(ax=axs[2], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Hemirotifera", palette="seismic")
axs[2].set_xlabel("Hemirotifera hypothesis", fontsize=12)
axs[2].set_ylabel("")
#Increase size of tick labels
for tick in axs[2].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[2].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
        
sns.boxplot(ax=axs[3], data=no_platy_reduced_cols_df, y=no_platy_reduced_cols_df["LB score (st. dev.)"], x="Pararotatoria", palette="seismic")
axs[3].set_xlabel("Pararotatoria hypothesis", fontsize=12)
axs[3].set_ylabel("")
#Increase size of tick labels
for tick in axs[3].xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in axs[3].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)

fig.supxlabel("Datasets supporting or not (1,0)  the different hypotheses of syndermatan relationships", fontsize=16)
fig.savefig("lb_score_median_all_hypotheses_boxplots.png")
fig.savefig("lb_score_median_all_hypotheses_boxplots.pdf")
fig.savefig("lb_score_median_all_hypotheses_boxplots.svg")

# %%
sns.jointplot(data=df_supermatrices, x=df_supermatrices["Prop. of missing data"], y=df_supermatrices["LB score (st. dev.)"], hue="Seisonidea-sister", kind="scatter",palette="seismic")

# %%
sns.jointplot(data=df_supermatrices, x=df_supermatrices["Average UFB support (site-heterogeneous model)"], y=df_supermatrices["LB score (st. dev.)"], hue="Seisonidea-sister", kind="scatter",palette="seismic")

# %%
sns.jointplot(data=df_supermatrices, x=df_supermatrices["Saturation score"], y=df_supermatrices["LB score (st. dev.)"], hue="Pararotatoria", kind="scatter",palette="seismic")

# %%
#Check support for datasets depending on outgroup inclusion

# %%
sns.countplot(data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Hemirotifera", palette="seismic")
# Out:
# <AxesSubplot:xlabel='No. of species', ylabel='count'>

# %%
sns.countplot(data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Seisonidea-sister", palette="seismic")
# Out:
# <AxesSubplot:xlabel='No. of species', ylabel='count'>

# %%
sns.countplot(data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Pararotatoria", palette="seismic")
# Out:
# <AxesSubplot:xlabel='No. of species', ylabel='count'>

# %%
sns.countplot(data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Lemniscea", palette="seismic")
# Out:
# <AxesSubplot:xlabel='No. of species', ylabel='count'>

# %%
#Create common plot for no species and inference of major clades

# %%
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(16,14), tight_layout=True, sharey=True, sharex=True)
fig.suptitle("number of trees supporting or not (1,0) the four tested syndermatan clades depending on the taxon sampling of the supermatrices", fontsize=16)
fig.supxlabel("Number of species in the dataset")
fig.supylabel("Number of phylogenetic trees")

sns.countplot(ax=axs[0,0],data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Hemirotifera", palette="seismic")
axs[0,0].set(xlabel="")
sns.countplot(ax=axs[0,1],data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Pararotatoria", palette="seismic")
axs[0,1].set(xlabel="")
sns.countplot(ax=axs[1,0],data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Lemniscea", palette="seismic")
axs[1,0].set(xlabel="")
sns.countplot(ax=axs[1,1],data=df_supermatrices, x=df_supermatrices["No. of species"], hue="Seisonidea-sister", palette="seismic")
axs[1,1].set(xlabel="")
plt.savefig("number_inferred_trees_hypotheses.no_species.png")
plt.savefig("number_inferred_trees_hypotheses.no_species.pdf")
plt.savefig("number_inferred_trees_hypotheses.no_species.svg")

# %%
#Create common plot for no species and inference of major clades (by removing the effect of site removal)
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(16,14), tight_layout=True, sharey=True, sharex=True)
fig.suptitle("Inference or not (1,0) of syndermatan clades from supermatrices with distant outgroup removed (output of site removal are not included)", fontsize=16)
fig.supxlabel("Number of species in the dataset")
fig.supylabel("Number of phylogenetic trees")

df_in_out=df_supermatrices[df_supermatrices["Removal of sites with unique amino acids for some or all species"]!="output datasets"]

df_in_out
sns.countplot(ax=axs[0,0],data=df_in_out, x=df_in_out["No. of species"], hue="Hemirotifera", palette="seismic")
axs[0,0].set(xlabel="")
sns.countplot(ax=axs[0,1],data=df_in_out, x=df_in_out["No. of species"], hue="Pararotatoria", palette="seismic")
axs[0,1].set(xlabel="")
sns.countplot(ax=axs[1,0],data=df_in_out, x=df_in_out["No. of species"], hue="Lemniscea", palette="seismic")
axs[1,0].set(xlabel="")
sns.countplot(ax=axs[1,1],data=df_in_out, x=df_in_out["No. of species"], hue="Seisonidea-sister", palette="seismic")
axs[1,1].set(xlabel="")
plt.savefig("number_inferred_trees_hypotheses.no_species.removed_siteremoval_outputs.png")
plt.savefig("number_inferred_trees_hypotheses.no_species.removed_siteremoval_outputs.pdf")
plt.savefig("number_inferred_trees_hypotheses.no_species.removed_siteremoval_outputs.svg")

# %%
#Check the effect of outgroup removal on the results of hypotheses

# %%
#Create common plot for no species and inference of major clades (by removing the effect of site removal and also matrices for which outgroups were not removed)
fig, axs = plt.subplots(nrows=1,ncols=2, figsize=(12,8), tight_layout=True, sharey=True, sharex=True)
fig.suptitle("Inference or not (1,0) of syndermatan clades from supermatrices when distant outgroup was removed", fontsize=16)
fig.supxlabel("Input and output datasets used for removing distantly related outgroups)")
fig.supylabel("Number of phylogenetic trees")

df_in_out=df_supermatrices[(df_supermatrices["Supermatrix ID"]=="supermatrix E")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix F")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix A50.1")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix A50.2")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix B50.1")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix B50.2")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix C50.1")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix C50.2")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix D50.1")|\
                           (df_supermatrices["Supermatrix ID"]=="supermatrix D50.2")]

df_in_out
sns.countplot(ax=axs[0],data=df_in_out, x=df_in_out["No. of species"], hue="Hemirotifera", palette="seismic")
axs[0].set(xlabel="")
sns.countplot(ax=axs[1],data=df_in_out, x=df_in_out["No. of species"], hue="Seisonidea-sister", palette="seismic")
axs[1].set(xlabel="")
plt.savefig("number_inferred_trees_hypotheses.no_species.input_output_outgroup_removal.png")
plt.savefig("number_inferred_trees_hypotheses.no_species.input_output_outgroup_removal.pdf")
plt.savefig("number_inferred_trees_hypotheses.no_species.input_output_outgroup_removal.svg")
#All analyses supported Lemniscea and 0 supported Pararotatoria

# %%
#Comparison between datasets that were used as input for site removal with output datasets
#Basically checking the effect of site removal on several properties of amino-acid supermatrices

# %%
#Comparison among supermatrices before and after site removal
fig = plt.figure(tight_layout=True)
df_site_removal=df_supermatrices[(df_supermatrices["Removal of sites with unique amino acids for some or all species"]=="input datasets") | (df_supermatrices["Removal of sites with unique amino acids for some or all species"]=="output datasets")] 
joint =sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["TORCV"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")

joint.ax_joint.set_xlabel("TORCV", fontsize=14)
joint.ax_joint.set_ylabel("LB score (st. dev.)", fontsize=14)

for tick in joint.ax_joint.xaxis.get_major_ticks():
                tick.label.set_fontsize(12)      
for tick in  joint.ax_joint.yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
      
joint.ax_joint.legend(title="Alignment-site removal based on unique amino acids", title_fontsize=12,fontsize=12)

plt.savefig("lb_score_TORCV_input_output.png")
plt.savefig("lb_score_TORCV_input_output.pdf")
plt.savefig("lb_score_TORCV_input_output.svg")

# %%
fig = plt.figure(tight_layout=True)
df_site_removal=df_supermatrices[(df_supermatrices["Removal of sites with unique amino acids for some or all species"]=="input datasets") | (df_supermatrices["Removal of sites with unique amino acids for some or all species"]=="output datasets")] 
df_exclude_G=df_site_removal[df_site_removal["Supermatrix ID"]!="supermatrix G"]
sns.jointplot(data=df_exclude_G, y=df_exclude_G["LB score (st. dev.)"], x=df_exclude_G["TORCV"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_TORCV_input_output.exclude_G.png")
plt.savefig("lb_score_TORCV_input_output.exclude_G.pdf")
plt.savefig("lb_score_TORCV_input_output.exclude_G.svg")

# %%
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["Saturation score"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_saturation_input_output.png")
plt.savefig("lb_score_saturation_input_output.pdf")
plt.savefig("lb_score_saturation_input_output.svg")

# %%
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["Prop. of singleton sites"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_prop_singleton_input_output.png")
plt.savefig("lb_score_prop_singleton_input_output.pdf")
plt.savefig("lb_score_prop_singleton_input_output.svg")

# %%
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["Prop. of PI sites"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_prop_PI_input_output.png")
plt.savefig("lb_score_prop_PI_input_output.pdf")
plt.savefig("lb_score_prop_PI_input_output.svg")

# %%
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["Prop. of missing data"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_prop_missing_input_output.png")
plt.savefig("lb_score_prop_missing_input_output.pdf")
plt.savefig("lb_score_prop_missing_input_output.svg")

# %%
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["RCFV"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_prop_RCFV_input_output.png")
plt.savefig("lb_score_prop_RCFV_input_output.pdf")
plt.savefig("lb_score_prop_RCFV_input_output.svg")

# %%
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["Prop. of rejected symmetry tests"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_prop_prop_rejected_input_output.png")
plt.savefig("lb_score_prop_prop_rejected_input_output.pdf")
plt.savefig("lb_score_prop_prop_rejected_input_output.svg")

# %%
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["Average P-distance"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_avg_pdist_input_output.png")
plt.savefig("lb_score_avg_pdist_input_output.pdf")
plt.savefig("lb_score_avg_pdist_input_output.svg")

# %%
#df_supermatrices.columns
fig = plt.figure(tight_layout=True)
sns.jointplot(data=df_site_removal, y=df_site_removal["LB score (st. dev.)"], x=df_site_removal["Average UFB support (site-heterogeneous model)"], hue="Removal of sites with unique amino acids for some or all species", palette="seismic")
plt.savefig("lb_score_avg_UFB_input_output.png")
plt.savefig("lb_score_avg_UFB_input_output.pdf")
plt.savefig("lb_score_avg_UFB_input_output.svg")

# %%
#Make one plot effects of site removal

# %%
#Checking hypotheses between input and outputs of site removal

# %%
fig = plt.figure(figsize=(6,4))
sns.countplot(data=df_site_removal, x=df_site_removal["Removal of sites with unique amino acids for some or all species"], hue="Hemirotifera", palette="seismic")
plt.xlabel("Alignment-site removal based on presence of unique amino acids")
# Out:
# Text(0.5, 0, 'Alignment-site removal based on presence of unique amino acids')

# %%
sns.countplot(data=df_site_removal, x=df_site_removal["Removal of sites with unique amino acids for some or all species"], hue="Pararotatoria", palette="seismic")
plt.legend(loc='upper center', title="Pararotatoria")

# %%
sns.countplot(data=df_site_removal, x=df_site_removal["Removal of sites with unique amino acids for some or all species"], hue="Seisonidea-sister", palette="seismic")
# Out:
# <AxesSubplot:xlabel='Removal of sites with unique amino acids for some or all species', ylabel='count'>

# %%
sns.countplot(data=df_site_removal, x=df_site_removal["Removal of sites with unique amino acids for some or all species"], hue="Lemniscea", palette="seismic")
# Out:
# <AxesSubplot:xlabel='Removal of sites with unique amino acids for some or all species', ylabel='count'>

# %%
#Make one plot for all hypothesis (input and output datasets of site removal strategies)

# %%
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(14,12), tight_layout=True, sharey=True, sharex=True)
fig.supxlabel("Input and output sets of supermatrices used in the alignment-site removal approach", fontsize=16)
fig.supylabel("Number of inferred phylogenetic trees", fontsize=16)

df_in_out=df_supermatrices[(df_supermatrices["Removal of sites with unique amino acids for some or all species"]=="input datasets") | (df_supermatrices["Removal of sites with unique amino acids for some or all species"]=="output datasets")]

#First subplot
sns.countplot(ax=axs[0,0],data=df_in_out, x=df_in_out["Removal of sites with unique amino acids for some or all species"], hue="Hemirotifera", palette="seismic")
axs[0,0].set_xlabel("")
axs[0,0].set_ylabel("Count", fontsize=14)
#Increase size of tick labels
for tick in axs[0,0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)      

#Second subplot
sns.countplot(ax=axs[0,1],data=df_in_out, x=df_in_out["Removal of sites with unique amino acids for some or all species"], hue="Pararotatoria", palette="seismic")
axs[0,1].set_xlabel("")
axs[0,1].set_ylabel("")

#Third subplot
sns.countplot(ax=axs[1,0],data=df_in_out, x=df_in_out["Removal of sites with unique amino acids for some or all species"], hue="Seisonidea-sister", palette="seismic")
axs[1,0].set_xlabel("")
axs[1,0].set_ylabel("Count", fontsize=14)
#Increase size of tick labels
for tick in axs[1,0].yaxis.get_major_ticks():
                tick.label.set_fontsize(12)
for tick in axs[1,0].xaxis.get_major_ticks():
                tick.label.set_fontsize(14)   

#Fourth subplot
sns.countplot(ax=axs[1,1],data=df_in_out, x=df_in_out["Removal of sites with unique amino acids for some or all species"], hue="Lemniscea", palette="seismic")
axs[1,1].set_xlabel("")
axs[1,1].set_ylabel("")
for tick in axs[1,1].xaxis.get_major_ticks():
                tick.label.set_fontsize(14)
        
#increase legend size for all subplots
axs[0,0].legend(title="Hemirotifera", title_fontsize=14,fontsize=14)
axs[0,1].legend(title="Pararotatoria", title_fontsize=14,fontsize=14)
axs[1,0].legend(title="Seisonidea-sister", title_fontsize=14,fontsize=14)
axs[1,1].legend(title="Lemniscea", title_fontsize=14,fontsize=14)


plt.savefig("number_inferred_trees_hypotheses.site_removal_strategy.png")
plt.savefig("number_inferred_trees_hypotheses.site_removal_strategy.pdf")
plt.savefig("number_inferred_trees_hypotheses.site_removal_strategy.svg")

# %%
#Checking the effect of site-heterogeneous model on the monophyly of Syndermata

# %%
sns.countplot(data=df_supermatrices, x="Monophyly of Syndermata (site-heterogeneous model)", palette="seismic")
# Out:
# <AxesSubplot:xlabel='Monophyly of Syndermata (site-heterogeneous model)', ylabel='count'>

# %%
sns.countplot(data=df_supermatrices, x="Monophyly of Syndermata (site-homogeneous model)", palette="seismic")
# Out:
# <AxesSubplot:xlabel='Monophyly of Syndermata (site-homogeneous model)', ylabel='count'>

# %%
#make one plot 
from matplotlib.ticker import FormatStrFormatter

fig2, axes = plt.subplots(nrows=1,ncols=2, figsize=(10,8), tight_layout=True, sharey=True)
fig2.suptitle("Number of phylogenetic trees supporting or not (1,0) the monophyly of Syndermata", fontsize=18)

sns.countplot(ax=axes[0],data=df_supermatrices, x="Monophyly of Syndermata (site-heterogeneous model)", palette="seismic")
axes[0].xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
axes[0].set_xlabel("site-heterogeneous model", fontsize=16)
axes[0].set_ylabel("Number of inferred phylogenetic trees", fontsize=16)


for tick in axes[0].xaxis.get_major_ticks():
                tick.label.set_fontsize(14)
for tick in axes[0].yaxis.get_major_ticks():
                tick.label.set_fontsize(14)

sns.countplot(ax=axes[1],data=df_supermatrices, x="Monophyly of Syndermata (site-homogeneous model)", palette="seismic")
axes[1].xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
axes[1].set_xlabel("site-homogeneous model", fontsize=16)
axes[1].set_ylabel("", fontsize=16)


for tick in axes[1].xaxis.get_major_ticks():
                tick.label.set_fontsize(14)
for tick in axes[1].yaxis.get_major_ticks():
                tick.label.set_fontsize(14)

plt.savefig("monophyly_syndermata_based_on_evolutionary_model.png")
plt.savefig("monophyly_syndermata_based_on_evolutionary_model.pdf")
plt.savefig("monophyly_syndermata_based_on_evolutionary_model.svg")

# %%
pd. __version__
# Out:
# '1.4.3'

# %%
sns.__version__
# Out:
# '0.11.2'
